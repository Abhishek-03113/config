# %%
import numpy as np 
import pandas as pd 
import cv2 as cv 
import tensorflow as tf 
import matplotlib.pyplot as plt
import mediapipe

# %matplotlib inline
# Out:
# 2023-09-13 20:46:14.575503: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-13 20:46:17.895163: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !yolo detect predict model =yolov8m.pt source ="test1.mp4"
# Out:
# /bin/bash: /home/xcal/anaconda3/envs/Sign/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Ultralytics YOLOv8.0.176 🚀 Python-3.11.4 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# video 1/1 (1/766) /home/xcal/SIH-2023/test1.mp4: 384x640 5 persons, 2 bottles, 6 chairs, 6 tvs, 1 keyboard, 175.7ms
# video 1/1 (2/766) /home/xcal/SIH-2023/test1.mp4: 384x640 5 persons, 2 bottles, 6 chairs, 9 tvs, 1 keyboard, 28.4ms
# video 1/1 (3/766) /home/xcal/SIH-2023/test1.mp4: 384x640 5 persons, 1 bottle, 6 chairs, 7 tvs, 1 keyboard, 28.5ms
# video 1/1 (4/766) /home/xcal/SIH-2023/test1.mp4: 384x640 5 persons, 6 chairs, 7 tvs, 1 keyboard, 28.4ms
# video 1/1 (5/766) /home/xcal/SIH-2023/test1.mp4: 384x640 5 persons, 2 bottles, 6 chairs, 9 tvs, 28.8ms
# video 1/1 (6/766) /home/xcal/SIH-2023/test1.mp4: 384x640 5 persons, 1 bottle, 5 chairs, 10 tvs, 28.4ms
# ...

# %%
import os

# %%
video = cv.VideoCapture("runs/detect/predict/test1.avi")

while video.isOpened():
    ret,frame = video.read()

    if ret == True:
        cv.imshow("frame",frame)
    else:
        break


    if cv.waitKey(10) & 0xff == ord('q'):
        break


video.release()
cv.destroyAllWindows()

# %%
data_dir = "runs/detect/predict2/"
dircontent = list(os.scandir(data_dir))

# %%
mp4Files = [[f.name[:-4], os.path.abspath(f.name)] for f in dircontent if f.name.lower().endswith('.avi')]

# %%
cap = cv.VideoCapture("runs/detect/predict/test.avi")
while cap.isOpened():
    ret, frame = cap.read()

    cv.imshow("window",frame)
    
    if cv.waitKey(10) & 0xff==ord('q'):
        break


cap.release()
cv.destroyAllWindows()
